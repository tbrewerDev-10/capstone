# %%
import pyarrow.parquet as pq
import pandas as pd

trips_2011 = pq.read_table('./TaxiCab/yellow_tripdata_2011-01.parquet')
trips_2011 = trips_2011.to_pandas()
# trips_2019 = pq.read_table('./TaxiCab/yellow_tripdata_2019-07.parquet')
# trips_2019 = trips_2019.to_pandas()
trips_2020 = pq.read_table('./TaxiCab/yellow_tripdata_2020-07.parquet')
trips_2020 = trips_2020.to_pandas()
# trips_2021 = pq.read_table('./TaxiCab/yellow_tripdata_2021-07.parquet')
# trips_2021 = trips_2021.to_pandas()
# trips_2023 = pq.read_table('./TaxiCab/yellow_tripdata_2023-01.parquet')
# trips_2023 = trips_2023.to_pandas()

# %%
trips_2011 = trips_2011.drop_duplicates()
trips_2011.shape
# Out:
# (13464885, 19)

# %%
trips_2011.isna().sum()
# Out:
# VendorID                        0
# tpep_pickup_datetime            0
# tpep_dropoff_datetime           0
# passenger_count                 0
# trip_distance                   0
# RatecodeID                      0
# store_and_fwd_flag        6738230
# PULocationID                    0
# DOLocationID                    0
# payment_type                    0
# fare_amount                     0
# extra                           0
# mta_tax                         0
# tip_amount                      0
# tolls_amount                    0
# improvement_surcharge           0
# total_amount                    0
# congestion_surcharge     13464884
# airport_fee              13464884
# dtype: int64

# %%
trips_2011 = trips_2011.drop(columns=['store_and_fwd_flag', 'congestion_surcharge', 'airport_fee'], axis=1)

# %%
trips_2011.head(3)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0         2  2011-01-01 00:10:00   2011-01-01 00:12:00                4  \
# 1         2  2011-01-01 00:04:00   2011-01-01 00:13:00                4
# 2         2  2011-01-01 00:14:00   2011-01-01 00:16:00                4
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type
# 0            0.0           1           145           145             1  \
# 1            0.0           1           264           264             1
# 2            0.0           1           264           264             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount
# 0          2.9    0.5      0.5        0.28           0.0  \
# 1          5.7    0.5      0.5        0.24           0.0
# 2          2.9    0.5      0.5        1.11           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.0          4.18
# 1                    0.0          6.94
# ...

# %%
trips_2011[['tpep_pickup_datetime', 'tpep_dropoff_datetime']] = trips_2011[['tpep_pickup_datetime', 'tpep_dropoff_datetime']].astype(str)
trips_2011[['Date', 'Pickup_Time']] = trips_2011.tpep_pickup_datetime.str.split(' ', expand=True)
trips_2011.drop('Pickup_Time', axis = 1, inplace=True)
trips_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13464885 entries, 0 to 13464996
# Data columns (total 17 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        int64
#  4   trip_distance          float64
#  5   RatecodeID             int64
#  6   PULocationID           int64
#  7   DOLocationID           int64
#  8   payment_type           int64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  Date                   object
# dtypes: float64(8), int64(6), object(3)
# memory usage: 1.8+ GB

# %%
days2011 = trips_2011.groupby('Date').agg({'passenger_count':'sum', 'trip_distance':'sum', 'fare_amount':'sum', 'tip_amount':'sum', 'total_amount':'sum'})
days2011
# Out:
#             passenger_count  trip_distance  fare_amount  tip_amount
# Date
# 2011-01-01           280656      557300.60   1907741.39   113850.80  \
# 2011-01-02           228791      502939.30   1661813.67   112074.68
# 2011-01-03           617158     1081492.86   3721946.66   291303.58
# 2011-01-04           662239     1105445.19   3962917.69   326928.93
# 2011-01-05           708838     1144248.14   4180747.89   357845.12
# 2011-01-06           769383     1235020.34   4534817.31   400228.22
# 2011-01-07           805322     1220136.17   4461342.48   389277.37
# 2011-01-08           881114     1283498.91   4573953.68   368959.67
# 2011-01-09           781828     1287226.71   4403716.79   376921.10
# 2011-01-10           717053     1191636.89   4298778.32   394450.62
# 2011-01-11           755305     1188461.09   4495311.85   425134.03
# 2011-01-12           590610      865971.12   3180507.78   307810.38
# 2011-01-13           786607     1293240.77   4848475.21   455775.00
# ...

# %%
trips_2020 = trips_2020.drop(columns=['store_and_fwd_flag', 'RatecodeID', 'congestion_surcharge', 'airport_fee'], axis=1)
trips_2020['passenger_count'] = trips_2020['passenger_count'].fillna(trips_2020['passenger_count'].mean())
trips_2020.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
trips_2020[['tpep_pickup_datetime', 'tpep_dropoff_datetime']] = trips_2020[['tpep_pickup_datetime', 'tpep_dropoff_datetime']].astype(str)
trips_2020[['Date', 'Pickup_Time']] = trips_2020.tpep_pickup_datetime.str.split(' ', expand=True)
trips_2020.drop('Pickup_Time', axis = 1, inplace=True)
trips_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800412 entries, 0 to 800411
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               800412 non-null  int64
#  1   tpep_pickup_datetime   800412 non-null  object
#  2   tpep_dropoff_datetime  800412 non-null  object
#  3   passenger_count        800412 non-null  float64
#  4   trip_distance          800412 non-null  float64
#  5   PULocationID           800412 non-null  int64
#  6   DOLocationID           800412 non-null  int64
#  7   payment_type           800412 non-null  int64
#  8   fare_amount            800412 non-null  float64
#  9   extra                  800412 non-null  float64
#  10  mta_tax                800412 non-null  float64
#  11  tip_amount             800412 non-null  float64
#  12  tolls_amount           800412 non-null  float64
#  13  improvement_surcharge  800412 non-null  float64
# ...

# %%
days2020 = trips_2020.groupby('Date').agg({'passenger_count':'sum', 'trip_distance':'sum', 'fare_amount':'sum', 'tip_amount':'sum', 'total_amount':'sum'})
days2020 = days2020.iloc[3:-1]
days2020
# Out:
#             passenger_count  trip_distance  fare_amount  tip_amount
# Date
# 2020-07-01     34931.449899       79107.66    345909.87    44521.04  \
# 2020-07-02     37687.453180       87353.57    379152.96    50739.05
# 2020-07-03     28627.360904      107865.44    277800.95    33726.78
# 2020-07-04     20297.357623       53877.85    211106.16    25471.09
# 2020-07-05     20400.757486       57657.77    221052.89    28602.15
# 2020-07-06     33655.610665       78511.37    333079.05    44701.08
# 2020-07-07     36051.901710       79418.33    342447.60    45822.39
# 2020-07-08     36936.967603       83335.95    362272.11    47714.84
# 2020-07-09     39753.291595      311639.58    386928.17    51462.94
# 2020-07-10     32911.537254       75513.36    328629.73    42045.60
# 2020-07-11     25694.084759       61195.23    245792.03    32921.89
# 2020-07-12     23915.813535       63564.78    249145.40    32881.53
# 2020-07-13     35906.608204       80968.66    339223.06    45733.59
# ...

# %%
trips_2019 = trips_2019.drop_duplicates()
trips_2019.shape
# Out:
# (6310418, 19)

# %%
trips_2020 = trips_2020.drop_duplicates()
trips_2020.shape
# Out:
# (800412, 19)

# %%
trips_2021 = trips_2021.drop_duplicates()
trips_2021.shape
# Out:
# (2821746, 19)

# %%
trips_2023 = trips_2023.drop_duplicates()
trips_2023.shape
# Out:
# (3066766, 19)

# %%
trips_2020.head(3)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0         1  2020-07-01 00:25:32   2020-07-01 00:33:39              1.0  \
# 1         1  2020-07-01 00:03:19   2020-07-01 00:25:43              1.0
# 2         2  2020-07-01 00:15:11   2020-07-01 00:29:24              1.0
#
#    trip_distance  PULocationID  DOLocationID  payment_type  fare_amount
# 0           1.50           238            75             2          8.0  \
# 1           9.50           138           216             1         26.5
# 2           5.85           230            88             2         18.5
#
#    tip_amount  tolls_amount  total_amount
# 0         0.0           0.0           9.3
# 1         0.0           0.0          27.8
# 2         0.0           0.0          22.3

# %%
trips_2019 = trips_2019.drop(columns=['store_and_fwd_flag', 'congestion_surcharge', 'airport_fee'], axis=1)
# trips_2019['passenger_count'] = trips_2019['passenger_count'].fillna(trips_2019['passenger_count'].mean())
trips_2019.isna().sum()
# Out:
# VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          33959
# trip_distance                0
# RatecodeID               33959
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# dtype: int64

# %%
trips_2021 = trips_2021.drop(columns=['RatecodeID', 'store_and_fwd_flag', 'extra', 'mta_tax', 'improvement_surcharge', 'congestion_surcharge', 'airport_fee'])
trips_2021['passenger_count'] = trips_2021['passenger_count'].fillna(trips_2021['passenger_count'].mean())
trips_2021.isna().sum()

# %%
trips_2023 = trips_2023.drop(columns=['RatecodeID', 'store_and_fwd_flag', 'extra', 'mta_tax', 'improvement_surcharge', 'congestion_surcharge', 'airport_fee'])
trips_2023['passenger_count'] = trips_2023['passenger_count'].fillna(trips_2023['passenger_count'].mean())
trips_2023.isna().sum()
